# %%
age=int(input("enter the age:"))
mark=int(input("enter the mark:"))
eligible= age>=18 and age<=25 and mark>=60
print(eligible)
# Out:
# enter the age: 10
# enter the mark: 20
# False

# %% [markdown]
# # task 2

# %%
username=input("enter the username:")
password=input("enter the password:")
login= username=="admin" and password=="1234"

print(login)
# Out:
# enter the username: abcd
# enter the password: 456
# False

# %% [markdown]
# # task 3

# %%
# task 3

a=int(input("enter the value"))
divisible= a>=50 and a<=100 and a%5==0
not_divisible=(a!= 100)
print(divisible)
# Out:
# enter the value 56
# False

# %% [markdown]
# # task 4

# %%
num1=int(input("enter the value"))
num2=int(input("enter the value"))
num3=int(input("enter the value"))

print(num1>num2)
print(num1>num3)
print(num2>num3)
# Out:
# enter the value 10
# enter the value 20
# enter the value 8
# False
# True
# True

# %% [markdown]
# # task 5

# %%
n=str(input("enter the value"))
print(n.upper())
# Out:
# enter the value suhani
# SUHANI

# %%
n=str(input("enter the value"))
print(n.lower())
# Out:
# enter the value suhani
# suhani

# %%
n=str(input("enter the value"))
print(len(n))
# Out:
# enter the value suhani
# 6

# %%
n=str(input("enter the value"))
print(n[:3])
# Out:
# enter the value suhani
# suh

# %%
n=str(input("enter the value"))
print(n[-3:])
# Out:
# enter the value suhani
# ani

# %% [markdown]
# # task 6

# %%
s=input("enter the value")
print(s[:10])
# Out:
# enter the value mynameissuhani
# mynameissu

# %%
s=input("enter the value")
print(s[-10:])
# Out:
# enter the value mynameissuhanidatal
# uhanidatal

# %%
k=input("enter the value")
print(k[ ::2])
# Out:
# enter the value suhani datal
# shn aa

# %% [markdown]
# # task 7

# %%
n=input("enter any value:")
print( n==n [::-1] )
# Out:
# enter any value: radar
# True

# %% [markdown]
# # task 8

# %%
m= str(input("enter the value"))
if len (m) >=8 and ("@" or "#" in m):
    print("strong password")
else:
    print("weak password")
# Out:
# enter the value suhanidatal@gmail.com
# strong password

# %%
sub1=int(input("enter the sub1:"))
sub2=int(input("enter the sub1:"))
sub3=int(input("enter the sub1:"))

if sub1>=40 and sub2>=40 and sub3>=40:
    print("pass")
else:
    print("fail")
# Out:
# enter the sub1: 34
# enter the sub1: 67
# enter the sub1: 89
# fail

# %%
n=int(input("enter the value"))
if n>=0 and n%2==0:
      print("positive or even")
else:
      print("negative or odd")
# Out:
# enter the value -2
# negative or odd

# %%
n=input("enter the value")
print("revrse:",n[::-1])
# Out:
# enter the value latur
# revrse: rutal

# %%
n=input("enter the value")
count=0

for i in n:
    if i in "aeiouAEIOU":
        count = count+1
print(count)
# Out:
# enter the value latur
# 2

# %%
n=input("enter the value")
print(n[:3])
# Out:
# enter the value 9284842974
# 928

# %%
n=input("enter the value")
print(n[3:6])
# Out:
# enter the value 9284842974
# 484

# %%
n=input("enter the value")
print(n[-4:])
# Out:
# enter the value 9284842974
# 2974

# %%
n=str(input("enter the value"))
if len (n)>=5 and ( n[0]=="A" or n[0]=="a" in n) :
    print("valid")
else:
    print("invalid")
# Out:
# enter the value suhaniii
# invalid

# %%
n=input("Enter the String:")
print(n)
# Out:
# Enter the String: dipali
# dipali

# %% [markdown]
# # task 3

# %%
n=str(input("enter the  value"))
print(n[1:-1])
# Out:
# enter the  value latur
# atu

# %%
n=int(input("enter the value"))
print(type(n))
# Out:
# enter the value 23
# <class 'int'>
