# %%
s=input("enter the value")
print(s[:5])
# Out:
# enter the value suhani
# suhan

# %%
s=input("enter the value")
print(s[-4:])
# Out:
# enter the value suhanidatal
# atal

# %%
s=input("enter the value")
print(s[2:9])
# Out:
# enter the value suhanianjirraodatal
# hanianj

# %%
s=input("enter the value")
print(s[::2])
# Out:
# enter the value suhanianjirraodatal
# shnajradtl

# %%
s=input("enter the value")
s.index("suhani")
# Out:
# enter the value suhani datal
# 0

# %%
s=input("enter the value")
print(s.upper())
# Out:
# enter the value suhani
# SUHANI

# %%
s=input("enter the value")
print(s.lower())
# Out:
# enter the value Suhani datal
# suhani datal

# %%
s=input("enter the value")
print(s.title())
# Out:
# enter the value SUhani datal
# Suhani Datal

# %%
s=input("enter the value")
print(s.capitalize())
# Out:
# enter the value SUHANI
# Suhani

# %%
s=input("enter the value")
print(s)
print(s.title())
# Out:
# enter the value suhani anjirrao datal
# suhani anjirrao datal
# Suhani Anjirrao Datal

# %%
s=input("enter the value")
print(s)
print(s.upper())
print(s.lower())
# Out:
# enter the value suhani anjirrao datal
# suhani anjirrao datal
# SUHANI ANJIRRAO DATAL
# suhani anjirrao datal

# %%
s=input("enter the value")
s.isalpha()
# Out:
# enter the value suhani
# True

# %%
s=input("enter the value")
s.isdigit()
# Out:
# enter the value 1234
# True

# %%
s=input("enter the value")
s.isalnum()
# Out:
# enter the value suhani123
# True

# %%
s=input("enter the value")
s.islower()
# Out:
# enter the value Suhani
# False

# %%
s=input("enter the value")
print((s.isalnum()and len(s) >=8) !=-1)
# Out:
# enter the value suhani123
# True

# %%
word=valid*(s.isalnum()and len(s) >=8) !=-1)!=-1) or "not valid"
# Out:
#   Cell In[19], line 1
#     word=(valid*(s.isalnum()and len(s) >=8) !=-1)!=-1) or "not valid"
#                                                      ^
# SyntaxError: unmatched ')'

# %%
n=input("enter the value")
print(n.find("h"))
# Out:
# enter the value suhani
# 2

# %%
n=input("enter the value")
print(n.find("h"))
# Out:
# enter the value geeta
# -1

# %%
n=input("enter the value:")
print(n.index("python"))
# Out:
# enter the value python is easy
# 0

# %%
n=input("enter the value")
print(n.find("y"))
# Out:
# enter the value suhani datal
# -1

# %%
n=input("enter the value")
print(n.index("y"))
# Out:
# enter the value suhani
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[27], line 2
#       1 n=input("enter the value")
# ----> 2 print(n.index("y"))
#
# ValueError: substring not found

# %%
chars = "abcdefghijklmnopqrstuvwxyz"
nums = "1234567890"

# %%
password = input("enter ur value")
length = len(password)
check = (password in chars) and (password in nums)
check
# Out:
# enter ur value hello1234
# False

# %%
password
# Out:
# 'hello1234'

# %%
char = False
nums_ = False
for i in password:
    if i in chars:
        char = True
    if i in nums:
        nums_ = True

if char and nums:
    if length >= 8:
        print("passed")
# Out:
# passed

# %%
full_name = input("Enter your name: ")
full_name_list = full_name.split()
print(full_name_list[0], full_name_list[-1])
# Out:
# Enter your name:  Sumit Kumar Sharma
# Sumit Sharma

# %%
n=input("enter your full name")
print(n.upper())
print(s.find(" "))
# Out:
# enter your full name  suhani
#  SUHANI
# -1

# %%
n=input("enter the name")
names=n.split()
print(names[0],names[-1])
# Out:
# enter the name suhani anjirrao datal
# suhani datal

# %%
n = input("Enter your password:")

if_numeric = n.isnumeric() #need to be false
if_alpha = n.isalpha() # need to be false

check = not if_numeric and not if_alpha and len(n) >= 8
check
# Out:
# Enter your password: t123
# False

# %%
"asdf1234".isnumeric()
# Out:
# False

# %%
"asdb1234".isalpha()
# Out:
# False

# %%
n=input("enter any value")
print(n[::-1])
print(n.title())
# Out:
# enter any value suhani
# inahus
# Suhani

# %%
n=str(input("enter any value"))
if_digit=n.isdigit()

check= not if_digit and len(n)<=10
check
# Out:
# enter any value 1234567891
# False
