# %%
n=input("enter the value")
print(n.replace(" ","_"))
# Out:
# enter the value suhani datal
# suhani_datal

# %%
n=input("enter the value")
print(n.rstrip())
print(n.lstrip())
# Out:
# enter the value      suhani datal
#      suhani datal
# suhani datal

# %%
n=input("enter the value")
n.startswith("hello")
# Out:
# enter the value my name is suhani
# False

# %%
n=input("enter the value")
n.endswith(".com")
# Out:
# enter the value suhanidatal@gmail.com
# True

# %%
#task 5
a=("apple,banana,mango")
a.split(",")
# Out:
# ['apple', 'banana', 'mango']

# %%
# task 6
fruits=["apple","banana","grapes","orange"]
print(" ".join(fruits))
# Out:
# apple banana grapes orange

# %%
#task7
list=[" python "," is "," awesome "]
list[0]=list[0].strip()
list[1]=list[1].strip()
list[2]=list[2].strip()

("-".join(list))
# Out:
# 'python-is-awesome'

# %%
n=input("enter the name")
names=n.split()
print(names[0],names[-1])
# Out:
# enter the name rahul kumar sharma
# rahul sharma

# %%
# task 9
n=input("enter the sentence:")
print(len(n.split()))
# Out:
# enter the sentence: suhani datal
# 2

# %%
# task 10
n=input("enter the value")
n.endswith("@gmail.com")
# Out:
# enter the value suhanidatal@gmail.com
# True

# %%
#task 11
n="hello world python"
n.replace("hello","everyone")
n.split()
# Out:
# ['hello', 'world', 'python']

# %%
# task 12
n1= input("enter city name:")
n2= input("enter city name:")
n3= input("enter city name:")
n4= input("enter city name:")
n5= input("enter city name:")

c=[n1,n2,n3,n4,n5]

print ("\n".join(c))
# Out:
# enter city name: latur
# enter city name: thane
# enter city name: pune
# enter city name: mumbai
# enter city name: amravti
# latur
# thane
# pune
# mumbai
# amravti

# %%
# task 13
n=("hello world")
n.strip()
n.title()
n.startswith("hello")
# Out:
# True

# %%
# task 14
n=(" it is bad habit")
a= n.split()
c= " ".join(a)
print(n.replace("bad","good"))
# Out:
#  it is good habit

# %%
# task 16
list=["10","20","30","40"]
("-".join(list))
# Out:
# '10-20-30-40'

# %%
n="it is good"
n.split()
n.remove().startswith("a,e,i,o,u")
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[57], line 3
#       1 n="it is good"
#       2 n.split()
# ----> 3 n.remove().startswith("a,e,i,o,u")
#
# AttributeError: 'str' object has no attribute 'remove'

# %%
m="my name is suhani"
n.replace(" ","-")
print(len(m))
# Out:
# 17

# %%
student=["siya","jiya","piya","riya"]
print(",".join(student))
student[0]="new student"
print
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 2
#       1 name=["siya","jiya","piya","riya"]
# ----> 2 print(",".join(student))
#
# NameError: name 'student' is not defined

# %%
p=(input("enter the paragraph"))
sent=p.split(".")
sent=[i.strip() for i in sent if i.strip()]
print("- " , "\n- ".join(sent))
# Out:
# enter the paragraph my name suhani.it is easy.
# -  my name suhani
# - it is easy
