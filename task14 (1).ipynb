# %%
# task1
n=["suhani","jiya","riya","priya","kiya"]
print(n)
# Out:
# ['suhani', 'jiya', 'riya', 'priya', 'kiya']

# %%
# task2
a=[10,20,30,40,50]
print(len(a))
print(type(a))
# Out:
# 5
# <class 'list'>

# %%
# task 3
b=[]
b.append([10,20,30])
b
# Out:
# [[10, 20, 30]]

# %%
# task 4
lst=[1,2,3]
lst.extend([4,5,6])
lst
# Out:
# [1, 2, 3, 4, 5, 6]

# %%
# task 5
lst=[10,20,30,40]
lst.insert(2,100)
lst
# Out:
# [10, 20, 100, 30, 40]

# %%
# task 6
lst=[10,20,30,40,50]
lst.remove(50)
lst
# Out:
# [10, 20, 30, 40]

# %%
# task 7
lst=[5,10,15,20]
lst.pop(3)
lst
# Out:
# [5, 10, 15]

# %%
# task 8
lst=[1,2,3,4,5]
lst.clear()
lst
# Out:
# []

# %%
# task 9
list=[10,15,25,30,40]
list.index(25)
# Out:
# 2

# %%
# task 10
a=[10,15,25,30,40]
print(a.index(25))
# Out:
# 2

# %%
# task 10 
c=[7,2,7,5,7,8]
print(c.count(7))
# Out:
# 3

# %%
# task 11
d=[45,12,78,23,56]
d.sort()
d
# Out:
# [12, 23, 45, 56, 78]

# %%
# task 12
e=[45,12,78,23,56]
e.sort(reverse=True)
e
# Out:
# [78, 56, 45, 23, 12]

# %%
# task 13
fruits=["apple","banana","mango","orange"]
fruits.sort(reverse=True)
fruits
# Out:
# ['orange', 'mango', 'banana', 'apple']

# %%
# task 14
list1=[1,2,3,4]
list2=list1.copy()
list2
# Out:
# [1, 2, 3, 4]

# %%
# task 15
n=input("write a sentence")
n.split()
# Out:
# write a sentence i love python program
# ['i', 'love', 'python', 'program']

# %%
# task 16
f=[10,12,13,14,15]
f.append(16)
f.append(17)
f.append(18)
f.sort(reverse=True)
f
# Out:
# [18, 17, 16, 15, 14, 13, 12, 10]

# %%
# task 17
list3=[ "it ","is","easy"]
list3.insert(0,"python")
list3.pop()
list3
# Out:
# ['python', 'it ', 'is']

# %%
# task 18
n1=input("enter the city:")
n2=input("enter the city:")
n3=input("enter the city:")
n4=input("enter the city:")
n5=input("enter the city:")
list5=[n1,n2,n3,n4,n5]
list5.reverse()
print(list5)
# Out:
# enter the city: latur
# enter the city: nashik
# enter the city: pune
# enter the city: gao
# enter the city: delhi
# ['delhi', 'gao', 'pune', 'nashik ', 'latur']

# %%
# task 19
data=[10,20,30,20,40,20]
data.remove(20)
data.remove(20)
data.remove(20)
data
# Out:
# [10, 30, 40]

# %%
# task 20
marks=[45,89,88,78]
marks.sort()
marks
print("lowest",marks[0])
print("highest",marks[-1])
# Out:
# lowest 45
# highest 89
