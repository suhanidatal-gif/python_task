# %%
n=int(input("enter the number:"))
if n>=0:
    print("positive")
else:
    print("nega")
# Out:
# enter the number: 6
# positive

# %%
# task 2

age=int(input("enter the value"))
if age>=18:
    print("you can vote")
else:  
    print("you cann't vote")
# Out:
# enter the value 11
# you cann't vote

# %%
# task 3

n1=int(input("enter te numb"))
n2=int(input("enter te numb"))
if n1>n2:
    print("largest ",n1)
else:
    print("lowest",n2)
# Out:
# enter te numb 78
# enter te numb 67
# largest  78

# %%
# task 4
n=int(input("enter the value"))
if n%2==0:
    print("even")
else:
    print("odd")
# Out:
# enter the value 9
# odd

# %%
# task 5

ch=input("enter the character:")
if ch=="A":
    print("character A")
else:
    print("not")
# Out:
# enter the character: A
# character A

# %%
# task 6
n1=int(input("enter te numb"))
if marks >= 40:
    print("pass")
else:
    print("fail")
# Out:
# enter the marks: 34
# fail

# %%
# task 7
num=int(input("enter te numb"))
if num%5==0:
    print("divisible by 5")
else:
    print("not divisible 5")
# Out:
# enter te numb 55
# divisible by 5

# %%
# task 8
n=int(input("enter te numb"))
if n>0:
    print("positive")
elif n<0:
    print("negavtive")
else:
    print("zero")
# Out:
# enter te numb 0
# zero

# %%
# task 9
n1=int(input("enter te numb"))
n2=int(input("enter te numb"))
n3=int(input("enter te numb"))

if n1>n3 and n1>n2:
    print("largest",n1)
elif n2>n3 and n2>n1:
    print("largest",n2)
else:
    print("largest",n3)
# Out:
# enter te numb 12
# enter te numb 13
# enter te numb 14
# largest 14

# %%
# task 10
year=int(input("enter the value:"))
if (year % 4==0 and year%100!=0) or year %400==0:
    print("leap year")
else:
    print("not leap year")
# Out:
# enter the value: 2020
# leap year

# %%
# task 11
ch=input("enter the character")
if ch in "AEIOUaeiou":
    print("vowel")
else:
    print("not vowel")
# Out:
# enter the character a
# vowel

# %%
# task 12
salary=int(input("enter the salary"))
if salary >50000:
    print("high")
elif salary>30000:
    print("medium")
else:
    print("low")
# Out:
# enter the salary 20000
# low

# %%
# task 13
cel=int(input("enter the temp"))
if cel>30:
    print("hot")
elif cel>=20 :
    print("warm")
else:
    print("cold")
# Out:
# enter the temp 18
# cold

# %%
# task 14
username=input("enter the value admin")
password=input("enter the value pass")
if username=="admin" and password=="1234":
    print("login successful")
else:
    print("login failed")
# Out:
# enter the value admin admin
# enter the value pass 123
# login failed

# %%
# task 15
n1=int(input("enter the value"))
n2=int(input("enter the value"))
n3=int(input("enter the value"))
if n1+n2>n3 and n2+n3>n1 and n1+n3>n2:
    if n1==n2==n3:
        print("equilateral")
    elif n1==n2 or n2==n3 or n1==n3:
        print("isosceles")
    else:
        print("Scalene")
else:
    print("invalid")
# Out:
# enter the value 45
# enter the value 56
# enter the value 78
# Scalene

# %%
# task 16
sub1=int(input("enter the marks"))
sub2=int(input("enter the marks"))
sub3=int(input("enter the marks"))
sub4=int(input("enter the marks"))
sub5=int(input("enter the marks"))

per=(sub1+sub2+sub3+sub4+sub5)/5
if per >=90:
    print("A+")
elif per >=80:
    print("A")
elif per >=70:
    print("B")
elif per >=60:
    print("C")
else:
    print("fail")
# Out:
# enter the marks 78
# enter the marks 77
# enter the marks 90
# enter the marks 88
# enter the marks 99
# A

# %%
# task 17
num=int(input("enter the number"))
if num%3==0 and num%5==0:
    print("FizzBuzz")
elif num % 3==0:
    print("Fizz")
elif num% 5==0:
    print("Buzz")
else:
    print(num)
# Out:
# enter the number 15
# FizzBuzz

# %%
# task 18
age=int(input("enter the age"))
gender=input("enter the gender")
if age>=18 and gender== "Male":
    print("Eligible for army")
elif age>=18 and gender=="Female":
    print("eligible for sevice")
else:
    print("not eligible")
# Out:
# enter the age 23
# enter the gender Male
# Eligible for army

# %%
# task 19
ch=input("enter the character")
if ch.isupper():
    print("upper")
elif ch.islower():
    print("lowwr")
elif ch.isdigit():
    print("digit")
else:
    print("special symbol")
# Out:
# enter the character mmm
# lowwr

# %%
# task 20

n1=int(input("enter three numb1"))
n2=int(input("enter three numb2"))
n3=int(input("enter three numb3"))

if n1>n2:
    n1,n2=n2,n1
elif n2>n3:
    n2,n3=n3,n2
elif n1>n3:
    n1,n3=n3,n1
print(n1,n2,n3)
# Out:
# enter three numb1 10
# enter three numb2 20
# enter three numb3 30
# 10 20 30
