# %%
# class name: shape
from abc import ABC,abstractmethod
class shape(ABC):
    @abstractmethod
    def area(self):
        pass
    @abstractmethod
    def perimeter(self):
        pass

class rectangle(shape):
    def __init__(self,length,width):
        self.length=length
        self.width=width

    def area(self):
        return self.length*self.width

    def perimeter(self):
        return 2*self.length+(self.width)

r=rectangle(10,20)
print("area",r.area())
print("perimeter",r.perimeter())
# Out:
# area 200
# perimeter 40

# %%
#2 vehical

class vehical(ABC):
    @abstractmethod
    def start(self):
        pass
    @abstractmethod    
    def stop(self):
        pass

class car(vehical):
    def start(self):
        print("car is start")
    def stop(self):
        print("car is stop")


c=car()
c.start()
c.stop()
# Out:
# car is start
# car is stop

# %%
# 3 
class animal(ABC):
    @abstractmethod
    def sound(self):
        pass

class dog(animal):
    def sound(self):
        print("bhouuu")

class cat(animal):
    def sound(self):
        print("meowww")


obj=dog()
obj1=cat()

obj.sound()
obj1.sound()
# Out:
# bhouuu
# meowww

# %%
# 4 payment
class payment(ABC):

    @abstractmethod
    def process_payment(self,amount):
        pass

class creditcard(payment):
    def process_payment(self,amount):
        print("pay payment by credit card",amount)

class cash(payment):
    def process_payment(self,amount):
        print("pay by cash",amount)
    
    


obj=creditcard()
obj2=cash()
obj.process_payment(200)
obj2.process_payment(300)
# Out:
# pay payment by credit card 200
# pay by cash 300

# %%
#5 report

class report(ABC):

    @abstractmethod
    def generate(self):
        pass

class pdfreport(report):
    def generate(self):
        print("it is pdf report")

class excelreport(report):
    def generate(self):
        print(" it is excel report")


obj1=pdfreport()
obj2=excelreport()
obj1.generate()
obj2.generate()
# Out:
# it is pdf report
#  it is excel report

# %%
# bank account

class bank(ABC):
    
    @abstractmethod
    
    def calculate_interest(self):
        pass

class savingacc(bank):
    
    
    def calculate_interest(self):
        print("calculate the interesting saving account")

obj1=savingacc()
obj1.calculate_interest()
# Out:
# calculate the interesting saving account

# %%
# 7 device

class device(ABC):

    @abstractmethod
    def turn_on(self):
        pass

    @abstractmethod
    def turn_off(self):
        pass

class laptop(device):
     def turn_on(self):
         print("light are on")
     def turn_off(self):
         print("light off")


clas=laptop()
clas.turn_on()
clas.turn_off()
# Out:
# light are on
# light off

# %%
# 8

class employee(ABC):

    @abstractmethod
    def calculate_bouns(self):
        pass

   

class manager(employee):
     def calculate_bouns(self):
         print("bounce calculation")
     


clas=manager()
clas.calculate_bouns()
# Out:
# bounce calculation

# %%
#9 transport

class tansp(ABC):

    @abstractmethod
    def move(self):
        pass

    @abstractmethod
    def fuel_type(self):
        pass

class car(tansp):
     def move(self):
         print("move the goods")
     def fuel_type(self):
         print("fuel is full")
class train(tansp):
    def move(self):
        print(" move the goods")
    def fuel_type(self):
         print("need fuel like coal")


clas=car()
tra=train()
clas.move()
clas.fuel_type()
tra.move()
tra.fuel_type()
# Out:
# move the goods
# fuel is full
#  move the goods
# need fuel like coal

# %%
# 10 notification
class notify(ABC):


    @abstractmethod
    def send(self,msg):
        pass

    
class email(notify):
     def send(self,msg):
         print("email msg",msg)
     
class sms(notify):
    def send(self,msg):
        print(" sms sent",msg)
    
obj1=email()
obj1.send("hello this is email msg")

obj2=sms()
obj2.send("this sms msg")
# Out:
# email msg hello this is email msg
#  sms sent this sms msg

# %%
# 11 filehandler
class file(ABC):
    @abstractmethod
    def read(self):
        pass

    @abstractmethod
    def write(self,data):
         pass
       

class text(file):
    
    
    def read(self):
         print("read the text")
    def write(self,data):
        print("write the file",data)

class csv(file):
    

    def read(self):
          print("read the text")
    def write(self,data):
        print("write the file",data)
    
obj=text()
obj.read()
obj.write("hello python")
# Out:
# read the text
# write the file hello python

# %%
# 13 calculator

class calcu(ABC):

    @abstractmethod
    def compute(self,a,b):
        pass

class add(calcu):
    def compute(self,a,b):
        return a+b
class mul(calcu):
    def compute(self,a,b):
        return a*b

o=add()
print("add",o.compute(10,20))
b=mul()
print("mul",b.compute(10,20))
# Out:
# add 30
# mul 200

# %%
# 14 database 
class data(ABC):
    @abstractmethod
    def connect(self):
        pass

    @abstractmethod
    def query(self,sql):
        pass


class mysql(data):
    def connect(self):
        print("my sql is connected")

    def query(self,sql):
        print("my query is excute",sql)


class mongo(data):
    def connect(self):
        print(" mangodb is connect")

    def query(self,sql):
        print("my query is excute",sql)



o=mysql()
b=mongo()
o.connect()
b.connect()
o.query("select * from student")
b.query("final select")
# Out:
# my sql is connected
#  mangodb is connect
# my query is excute select * from student
# my query is excute final select

# %%
from abc import ABC, abstractmethod
import math


class Shape(ABC):

    @abstractmethod
    def volume(self):
        pass

    @abstractmethod
    def surface_area(self):
        pass


class Cube(Shape):

    def __init__(self, side):
        self.side = side

    def volume(self):
        return self.side ** 3

    def surface_area(self):
        return 6 * self.side ** 2


class Sphere(Shape):

    def __init__(self, radius):
        self.radius = radius

    def volume(self):
        return (4 / 3) * math.pi * self.radius ** 3

    def surface_area(self):
        return 4 * math.pi * self.radius ** 2


c = Cube(3)
s = Sphere(2)

print("Cube volume:", c.volume())
print("Cube surface area:", c.surface_area())

print("Sphere volume:", s.volume())
print("Sphere surface area:", s.surface_area())
# Out:
# Cube volume: 27
# Cube surface area: 54
# Sphere volume: 33.510321638291124
# Sphere surface area: 50.26548245743669

# %%
# shape
from abc import ABC,abstractmethod
import math
class sha(ABC):
    def __init__(self,color):
        self.color=color

    @abstractmethod
    def area (self):
        pass

class circle(sha):
    def __init__(self,color,radius):
         super().__init__(color)
         self.radius=radius
    def area(self):
        return math.pi*self.radius**2



obj=circle("red",5)
print("color",obj.color)
print("area",obj.area())
# Out:
# color red
# area 78.53981633974483

# %%
# 17 vechile
class veh(ABC):

    def __init__(self,brand):
        self.brand=brand

    @abstractmethod
    def start(self):
        pass

    @abstractmethod
    def stop(self):
        pass

class car(veh):
    def __init__(self,brand):
        super().__init__(brand)

    def start(self):
        
        print("car is start",self.brand)
    def stop(self):
        print("car is stop",self.brand)
        
obj=car("toyata")
obj.start()
obj.stop()
# Out:
# car is start toyata
# car is stop toyata

# %%
# 18 animal

class animal(ABC):

    def __init__(self,name):
        self.name=name

    @abstractmethod
    def sound(self):
        pass

class dog(animal):
    def __init__(self,name):
        super().__init__(name)

    def sound(self):
        print("bhauuuu")

o=dog("laber")
print("dog name :",o.name)
o.sound()
# Out:
# dog name : laber
# bhauuuu

# %%
# 19 payment
class payment(ABC):

    def __init__(self,amount):
        self.amount=amount

    @abstractmethod
    def process_payment(self):
        pass

class credit(payment):
    def __init__(self,amount):
        super().__init__(amount)

    def process_payment(self):
        print("pay by creditcard",self.amount)

class cash(payment):
    def __init__(self,amount):
        super().__init__(amount)

    def process_payment(self):
        print("payment by cash",self.amount)


obj=credit(20000)
obj.process_payment()

obj1=cash(1000)
obj1.process_payment()
# Out:
# pay by creditcard 20000
# payment by cash 1000

# %%
# 20 employee

class empl(ABC):

    def __init__(self,name):
        self.name=name

    @abstractmethod
    def calcu_bonus(self):
        pass

class manager(empl):

    def __init__(self,name,amount):
        super().__init__(name)
        self.amount=amount
    def calcu_bonus(self):
        bonus=self.amount*10/100
        print("employee name",self.name)
        print("bonus",bonus)
               
obj=manager("diya",1000)
obj.calcu_bonus()
# Out:
# employee name diya
# bonus 100.0

# %%
# 21 report
class report(ABC):

    def __init__(self,title):
        self.title=title
        
    @abstractmethod
    def genrate(self):
        pass

class pdf(report):  

    def __init__(self,title):
        super().__init__(title)
        self.title=title
    def genrate(self): 
        print("Title of book : ",self.title)

ob=pdf("my rules")
ob.genrate()
# Out:
# Title of book :  my rules

# %%
# 22 bank acc
class bank(ABC):

    def __init__(self,balance):
        self.balance=balance

    @abstractmethod
    def cal_interest(self):
        pass

class saving(bank):
    def __init__ (self,balance):
        super().__init__(balance)
        
        

    def cal_interest(self):
        interest=self.balance*5/100
        print("interest",interest)

obj=saving(20000)
obj.cal_interest()
# Out:
# interest 1000.0

# %%
# device

class mob(ABC):

    def __init__(self,brand):
        self.brand=brand

    @abstractmethod
    def trun_on(self):
        pass

    @abstractmethod
    def trun_off(self):
        pass

class laptop(mob):

    def __init__(self,brand):
        super().__init__(brand)
        

    def trun_on(self):
        print(" trun on the mobile torch:",self.brand)

    def trun_off(self):
        print("trun off the mobile tourch:",self.brand)

lap=laptop("hp")
lap.trun_on()
lap.trun_off()
# Out:
#  trun on the mobile torch: hp
# trun off the mobile tourch: hp

# %%
# 24 transport
from abc import ABC,abstractmethod
import math

class transp(ABC):

    def __init__(self,speed):
        self.speed=speed

    @abstractmethod
    def move(self):
        pass

    @abstractmethod
    def fuel_type(self):
        pass


class car(transp):
    def __init__ (self,speed):
         super().__init__(speed)
    def move(self):
        print("car moving", self.speed)

    def fuel_type(self): 
        print("car use petrol", self.speed)

        
obj=car(120)
obj.move()
obj.fuel_type()
# Out:
# car moving 120
# car use petrol 120

# %%
#25 notification by supeer

class noti(ABC):

    def __init__(self,recipt):
        self.recipt=recipt

    @abstractmethod
    def send(self):
        pass  

class   email(noti):

    def __init__(self,recipt):
        super().__init__(recipt)

    def send(self):
        print("email msg:",self.recipt)

ob=email("abcd")
ob.send()
# Out:
# email msg: abcd
