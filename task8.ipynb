# %%
n=int(input("entr the value:"))
if n>0 and n%2==0:
    print("it is positive or even ")
else:
    print(" it is negative or odd")
# Out:
# entr the value: 9
#  it is negative or odd

# %%
# task 2

age=int(input("enter tehe age"))
if age >=18:
    if age>=60:
        print("senior citizen")
    else:
        print("adult")
else:     
    print(" tineeger")
# Out:
# enter tehe age 13
#  tineeger

# %%
# task 3
ch=input("enter the character")
if ch.isalpha():
    if ch.isupper():
        print("upper case")
    else:
        print("lower case")
else:
    print("invalid character")
# Out:
# enter the character W
# upper case

# %%
# task 4
# largest number using nested if else

n1=int(input("enter the value"))
n2=int(input("enter the value"))
n3=int(input("enter the value"))
if n1>n2:
    if n1>n3:
        print(n1)
    else:
        print(n3)
else:
    if n2>n3:
        print(n2)
    else:
        print(n3)
# Out:
# enter the value 10
# enter the value 20
# enter the value 30
# 30

# %%
# task 5
marks=int(input("enter the marks:"))
if marks>=40:
    if marks>=75:
        print("pass with disctnction")
    else:
        print("pass")
   
else:
    print("fail")
# Out:
# enter the marks: 80
# pass with disctnction

# %%
# task 6
n=int(input("enter the number:"))
if n%2==0 :
    if n%4==0:
        print("divisible by 2 and 4")
    else:
        print("it is divisible by 2")
else:
    print("it is by 2")
# Out:
# enter the number: 8
# divisible by 2 and 4

# %%
# task 7
user=input("user name:")

if user=="admin":
    passw=input("enter pass")
    if passw== "1234":
        print("login sucessful")
    else:
        print("login failed")
else:
    print("type correct login inf")
# Out:
# user name: admin
# enter pass 1234
# login sucessful

# %%
# task 8 " it is equilateral triangle 
a =int(input("enter the number:"))
b =int(input("enter the number:"))
c =int(input("enter the number:"))
if a+b>c and b+c>a and c>a+a:
    if a==b==c:
        print("equilaterial")
    else:
        print("isosceles")
else:
    print("Invalid traingle")
# Out:
# enter the number: 5
# enter the number: 5
# enter the number: 5
# scalene

# %%
# task 9
salary=int(input("enter the salary"))
years=int(input("enter the years"))
if salary >50000:
    if years>=5:
        print("senior manager")
    else:
        print("manager")
else:
    print("employee")
# Out:
# enter the salary 60000
# enter the years 6
# manager

# %%
# task 10  take charater if it vowel,consonant,digit,special charater
ch =input("enter the number:")
if ch.isalpha():
    if ch=="AEIOUaeiou":
        print("is vowel")
    else:
        print("consonant")
elif ch.isdigit():
    print("digit")
else:
    print("special symbol")
# Out:
# enter the number: 3
# digit

# %%
# task 11

year=int(input("enter the year:"))
if year %4==0:
    if year %100==0:
        if year %400==0:
            print("it is leap year")
        else:
            print("is not leap year")
    else:     
        print("it is leap year")
else:
    print("is not leap year")
# Out:
# enter the year: 2024
# it is leap year

# %%
# task 12
temp=int(input("ente the tempreture"))
if temp>30:
    print("hot")
elif temp>20:
    print("warm")
else:
    print("cold")
# Out:
# ente the tempreture 45
# hot

# %%
# task 13
n1=int(input("enter the number one"))
n2=int(input("enter the second number"))
n3=int(input("enter the third number"))
if n1==n2==n3:
    print("equal")
elif n1==n2 or n2==n3 or n1==n3:
    print("two are equal")
else:
    print("all different")
# Out:
# enter the number one 10
# enter the second number 10
# enter the third number 20
# two are equal

# %%
# task 14
n=int(input("enter the number:"))
if n>0:
    if n%2==0:
        print("it is positive or even")
    else:
        print("negative")
else:
    print("not positive")
# Out:
# enter the number: 3
# negative

# %%
# task 15
sub1=int(input("enter the sub1:"))
sub2=int(input("enter the sub1:"))
sub3=int(input("enter the sub1:"))
sub4=int(input("enter the sub1:"))
sub5=int(input("enter the sub1:"))

avg=(sub1+sub2+sub3+sub4+sub5)/5
if avg>=60:
    if sub1>40 and sub2>20 and sub3>40 and sub4>40 and sub5>40:
        print("pass")
    else:
        print("pass but better")
else:
    print("fail")
# Out:
# enter the sub1: 70
# enter the sub1: 55
# enter the sub1: 60
# enter the sub1: 70
# enter the sub1: 60
# pass

# %%
# 16
username=input("enter username")
passw=input("enter pass")
age=int(input("enter the age"))
if username=="admin" and passw=="123":
    if age>=18:
        print("login successful")
    else:
        print("age restriction")
else:
    print("invalid uaser name pass")
# Out:
# enter username admin
# enter pass 123
# enter the age 20
# login successful

# %%
# task 17
n=int(input("enter the number"))
if n%3==0:
    if n%5==0:
        print(" divisible by 3 and 5")
    else:
        print("divisible by 3")
else:
    print(" not divisible by 3")
# Out:
# enter the number 15
#  divisible by 3 and 5

# %%
# task 18
a=int(input("A"))
b=int(input("B"))
c=int(input("C"))

if a+b>c and b+c>a and c+a>b:
    if a*a+b*b==c*c and a*a+c*c==b*b and c*c+b*b==a*a:
        print("right angle triangle")
    else:
        print("not right angle triangle")
else:
    print("invalid triangle")
# Out:
# A 3
# B 4
# C 5
# not right angle triangle

# %%
# task 19
grade=input("enter")

if grade=="A":
    print("excellent")
elif grade=="B":
    print("good")
elif grade=="C":
    print("average")
elif grade=="D":
    print("not good")
# Out:
# enter A
# excellent

# %%
# task 20 
income=int(input("enter the income"))

if income>10000000:
    print("high income")
    if income>500000:
        print("

# %%
num=int(input("enter the number"))
if num>0:
    if num %3==0 and num %5==0:
         print("Fizzbuzz")
        
    elif num %3==0:
        print("Fizz")
    elif num %5==0:
        print("Buzz")
    else:
        print("not divisible by 3 or 5")
else:
    print("negative number")
# Out:
# enter the number 15
# Fizzbuzz

# %%
n1=int(input("enter the number"))
n2=int(input("enter the number2"))
n3=int(input("enter the number3"))

if n1==n2==n3:
    print("all three are equal")
    
    elif n1>n2:
        print(n1)
    else:
        print(n2)
else:
    elif n2>n3:
        print(n2)
    else:
        print(n3)
# Out:
#   Cell In[6], line 6
#     elif n1>n2:
#     ^
# SyntaxError: invalid syntax

# %%
a = int(input("Enter first number: "))
b = int(input("Enter second number: "))
c = int(input("Enter third number: "))

if a == b == c:
    print("All three numbers are equal")

else:

    if a > b and a > c:
        largest = a

    elif b > c:
        largest = b

    else:
        largest = c

    print("Largest Number =", largest)

    if largest % 2 == 0:
        print("Largest number is Even")

    else:
        print("Largest number is Odd")
# Out:
# Enter first number:  10
# Enter second number:  25
# Enter third number:  18
# Largest Number = 25
# Largest number is Odd

# %%
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 2
#       1 for i in range(1,11):
# ----> 2     remove.i
#
# NameError: name 'remove' is not defined
