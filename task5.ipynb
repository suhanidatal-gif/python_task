# %%
# task 1
dic={"name":"suhani","age":22,"city":"latur"}
print(dic)
# Out:
# {'name': 'suhani', 'age': 22, 'city': 'latur'}

# %%
# task 2
d={"a":1,"b":2,"c":3}
d.keys()
# Out:
# dict_keys(['a', 'b', 'c'])

# %%
# task 3
D={"a":1,"b":2}
print(D.values())
# Out:
# dict_values([1, 2])

# %%
# task 4
d={"name":"sumit","age":25}
d.get("name")
# Out:
# 'sumit'

# %%
# task 5
k=(1,2,3,4,5)
print((type(k)))
len(k)
# Out:
# <class 'tuple'>
# 5

# %%
# task 6
tup=(10,20,30,40,50)
tup.count(20)
# Out:
# 1

# %%
# task 7

s=(10,20,30,40)
s.index(30)
# Out:
# 2

# %%
# question 8
dic={"School":"KVL","class":9,"floor":"2nd"}
dic
# Out:
# {'School': 'KVL', 'class': 9, 'floor': '2nd'}

# %%
# question 9
d={"a":1,"b":2}
d.update({"c":3,"d":4})
d
# Out:
# {'a': 1, 'b': 2, 'c': 3, 'd': 4}

# %%
# question 10
student={"name":"Rahul","age":22,"city":"delhi"}
student.pop("age")
print(student)
# Out:
# {'name': 'Rahul', 'city': 'delhi'}

# %%
# question 11
x={"x":10,"y":20,"z":30}
x.popitem()
print(x)
# Out:
# {'x': 10, 'y': 20}

# %%
# question 12
original={"a":1,"b":2}
cop=original.copy()
print(cop)
# Out:
# {'a': 1, 'b': 2}

# %%
# question 13
keys={"red","green","blue"}
dict2=dict.fromkeys(keys,0)
print(keys)
# Out:
# {'green', 'red', 'blue'}

# %%
# question 14
tup=("name",10,40.50)
tup[1]="python"
print(tup)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[48], line 3
#       1 # question 14
#       2 tup=("name",10,40.50)
# ----> 3 tup[1]="python"
#       4 print(tup)
#
# TypeError: 'tuple' object does not support item assignment

# %%
# question 15
d={"name":"sumit"}
d.setdefault("age",25)
print(d)
# Out:
# {'name': 'sumit', 'age': 25}

# %%
# question 16
dict1={}
dict1.update({"cars":"tasla"})
dict1.update({"color":"grey"})
dict1.update({"model":"2026"})
dict1
# Out:
# {'cars': 'tasla', 'color': 'grey', 'model': '2026'}

# %%
# question 17
n1=input("enter first student marks:")
n2=input("enter first student marks:")
n3=input("enter first student marks:")

# %%
# question 17
tup1=(1,2,3,4,5,6)
x=tup1.index(3)
c=tup1.count(4)
print(x)
print(c)
# Out:
# 2
# 1

# %%
# question 18
d={}
n1=input("enter first student  name1:")
marks1=input("enter the marks first:")
d[n1]=marks1
print(d)
n1=input("enter first student  name2:")
marks2=input("enter the marks first:")
d[n1]=marks2
print(d)
n1=input("enter first student  name3:")
marks3=input("enter the marks first:")
d[n1]=marks3
print(d)
# Out:
# enter first student  name1: siya
# enter the marks first: 99
# {'siya': '99'}
# enter first student  name2: jiya
# enter the marks first: 90
# {'siya': '99', 'jiya': '90'}
# enter first student  name3: riya
# enter the marks first: 78
# {'siya': '99', 'jiya': '90', 'riya': '78'}

# %%
# question 19
data={"a":10,"b":20,"c":10}
print(list(data.items())[0])
# Out:
# ('a', 10)

# %%
# question 20
dict6={"name":"suhani","std":9,"school":"kvl","city":"latur","state":"maharashtra"}
h=dict6.copy()
dict6.clear()
print(h)
print(dict6)
# Out:
# {'name': 'suhani', 'std': 9, 'school': 'kvl', 'city': 'latur', 'state': 'maharashtra'}
# {}

# %%
#question 21
dict7={"name":"suhani","std":9,"school":"kvl","city":"latur"}
dict7.update({"name":"jiya"})
dict7.popitem()
print(dict7.items())
# Out:
# dict_items([('name', 'jiya'), ('std', 9), ('school', 'kvl')])

# %%
# question 22
tup6=(1,22,23,24,25,26,27,28)
tup6.index(26)
tup6.count(26)
l=list(tup6)
l.sort(reverse=True)
print(l)
# Out:
# [28, 27, 26, 25, 24, 23, 22, 1]

# %%
# question 23
d={}
n1=input("enter first student  name1:")
marks1=input("enter the marks first:")
d[n1]=marks1
print(d)
n1=input("enter first student  name2:")
marks2=input("enter the marks2:")
d[n1]=marks2
print(d)
n1=input("enter first student  name3:")
marks3=input("enter the marks3:")
d[n1]=marks3
n1=input("enter first student  name4:")
marks4=input("enter the marks4:")
d[n1]=marks4
print(d)
print("lowest",list(d.items())[-1])
print(" highest",max(d.values()))
# Out:
# enter first student  name1: h
# enter the marks first: 99
# {'h': '99'}
# enter first student  name2: g
# enter the marks2: 77
# {'h': '99', 'g': '77'}
# enter first student  name3: l
# enter the marks3: 90
# enter first student  name4: m
# enter the marks4: 45
# {'h': '99', 'g': '77', 'l': '90', 'm': '45'}
# lowest ('m', '45')
#  highest 99

# %%
# question 24
info={"name":"Aman","age":21,"city":"mumbai"}
cp=info.copy()
info.clear()
info
cp.update({"country":"India"})
print(cp)
print(info)
# Out:
# {'name': 'Aman', 'age': 21, 'city': 'mumbai', 'country': 'India'}
# {}

# %%
# question 25
data=(10,20,30,20,40,20,50)
d={}
d[0]=data.count(10)
d[0]=data.count(10)
d[0]=data.count(10)
d[0]=data.count(10)
d[0]=data.count(10)
print(d)
# Out:
# {0: 1}
