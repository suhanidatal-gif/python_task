# %% [markdown]
# # single line comment

# %%
print ("suhani")
# Out:
# suhani

# %% [markdown]
# # Multiple line comment

# %%
# first comment suhani 
# second comment : cocsit 
# third comment : full stack of data science

# %% [markdown]
# # Docstring comment

# %%
""" suhani datal """
# Out:
# ' suhani datal '

# %% [markdown]
# # indentation

# %%
if True:
    print("hello world")
    print("welcome to python")
# Out:
# hello world
# welcome to python

# %% [markdown]
# # Variable Declaration

# %%
name = "suhani"
print(type(name))
# Out:
# <class 'str'>

# %%
age = 22
print(type(age))
# Out:
# <class 'int'>

# %%
h=165.4
print(type(h))
# Out:
# <class 'float'>

# %%
is_student= "True"
print(type(is_student))
# Out:
# <class 'str'>

# %%
is_student=True
print(type(is_student))
# Out:
# <class 'bool'>

# %% [markdown]
# # variable naming rules

# %%
first_name= "suhani"
my_name= "suhani"
total_amount=27000
classes= "full stack data science"
score=88.00

# %% [markdown]
# # Arithmatic operation

# %%
a=int(input("enter any value a:"))
b=int(input("enter any value b:"))
add=a+b
diff=a-b
mul=a*b
div=a/b
floor=a//b
module=a%b
power=a**b
print("addition",add)
print("differenc",diff)
print("multiplication",mul)
print("divisionj",div)
print("floor division",floor)
print("modules",module)
print("powers",power)

# %% [markdown]
# ## Comparision Operator

# %% [markdown]
# ### x=int(input("enter any value x:"))
# y=int(input("enter any value y:"))
# eual=x==y
# nott=x!=y
# g=x<y
# s=x>y
# ge=x>=y
# le=x<=y
#
# print("equal",eual)
# print("not equal =",nott)
# print("greater=",g)
# print("smallerr=",s)
# print("greater than equal=",ge)
# print("less than qual=",le)

# %% [markdown]
# ## Assigment operater

# %%
c=10
c+=10
print(c)

# %%
c-=2
print(c)

# %%
c*=2
print(c)

# %%
c/=2
print(c)

# %%
c//=2
print(c)

# %%
c**=2
print(c)

# %% [markdown]
# ## Local VS global variable

# %%
college = "cocsit clg"

def info():
    global college
    print("college name",college)


    local= " dayanad college"
    print(" local college name",local)
    
info()
print("ouside college namen",college)
# Out:
# college name cocsit clg
#  local college name  dayanad college
# ouside college namen cocsit clg

# %% [markdown]
# ## Area and circumference

# %%
r=int(input("enter the value"))
pi=3.14
area= pi*r*r
circum=2*pi*r
print("area of circule",area)
print("circumference of circle",circum)
# Out:
# enter the value 10
# area of circule 314.0
# circumference of circle 62.800000000000004

# %% [markdown]
# ## Grade

# %%
marathi =int(input("enter the vaue marathi"))
english=int(input("enter the value english"))
hindi=int(input("enter the value hindi"))
science=int(input("enter the value science"))
math=int(input("enter the value math"))
geography=int(input("enter the value geography"))

total=marathi+english+hindi+science+math+geography
per=total/600

if per >=90:
    print("A+")
elif per >=80:
    print("A")
elif per >=70:
    print("B")
elif per >=60:
    print("C")
else:
    print("fail")
# Out:
# enter the vaue marathi 10
# enter the value english 2
# enter the value hindi 30
# enter the value science 40
# enter the value math 50
# enter the value geography 60
# fail

# %%
k=10
print(k)

# %%
age=int(input("enter the age"))
salary=int(input("enter the salary"))
if age>=16 and age<=60 and salary> 25000:
    print("eligible to loan")
else:
    print("not eligible to loan")
# Out:
# enter the age 15
# enter the salary 26000
# not eligible
