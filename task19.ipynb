# %%
# 1 
class acc:
    def __init__(self,balance):
        self.__balance=balance

    def deposit(self,amount):
        if amount>0:
            self.__balance+=amount
            print("deposite successful")
        else:
            print("amount is less")
    def withdraw(self,amount):
        if amount >0 and amount<=self.__balance:
            self.__balance-=amount
            print("reamaing ",self.__balance)



        else:
            print("amount is not available")
        
obj=acc(20000)
obj.deposit(1000)
obj.withdraw(5000)
# Out:
# deposite successful
# reamaing  16000

# %%
# class name method 

class name:
    def __init__(self,mark):
        self.__mark=mark

    def set_mark(self,mark):
        if mark >=0 and mark<=100:
            self.__mark=mark
            print("the mark is available")
        else:
            print("invalid mark")

    def get_mark(self):
        return self.__mark

obj=name(45)
print("old marks",obj.get_mark())


obj.set_mark(77)
print("new mark",obj.get_mark())
# Out:
# old marks 45
# the mark is available
# new mark 77

# %%
# 3 class name:employee
class name:
    def __init__(self,salary):
        self.__salary=salary
    def set_salary(self,new_salary):
        min_salary=self.__salary-(self.__salary*10/100)

        if new_salary>= min_salary:
            self.__salary=new_salary
            print("salary updated")
        else:
            print("salary cannot decrease by more than 10%")
    def get_salary(self):
        return self.__salary
    


obj=name(20000)
print("old salary",obj.get_salary())

obj.set_salary(1000)
print("old salary",obj.get_salary())
# Out:
# old salary 20000
# salary cannot decrease by more than 10%
# old salary 20000

# %%
# 4 class name=mobile

class mob:
    def __init__(self,price):
        self.__price=price

    def set_price(self,price):
        if price>0:
            self.__price=price
            print("it should always positive")

        else:
            print("it is negative")
    def get_price(self):
         return self.__price


obj=mob(200)
print("old salary",obj.get_salary())

obj.set_salary(1000)
print("old salary",obj.get_salary())
# Out:
# old price 200
# it is negative
# new price 200

# %%
# class name :person

class person:
    def __init__(self,age):
        self.__age=age

    def set_age(self,age):
        if age>=0 and age<=120:
             self.__age=age
             print("valid age")
        else:
             print("invalid age")
    def get_age(self):
        return self.__age

obj=person(20)
print("old age",obj.get_age())

obj.set_age(23)
print("new age",obj.get_age())
# Out:
# old age 20
# valid age
# new salary 23

# %%
# 6 class name :product
class pro:
    def __init__(self,price,stock):
        self.__price=price
        self.__stock=stock
    def update_price(self,new_price):
        if new_price>=0:
            self.__price=new_price
            print("price updated")
        else:
            print("price cannot negative")
    def update_stock(self,quantity):
         if self.__stock + quantity >=0:
             self.__stock+=quantity
             print("stock update")
         else:
             print("quantiy negative")
    def get_price(self):
        return self.__price
    def get_stock(self):
        return self.__stock

obj=pro(100,2)



print("Old price:", obj.get_price())
print("Old stock:", obj.get_stock())

obj.update_price(150)
obj.update_stock(5)

print("New price:", obj.get_price())
print("New stock:", obj.get_stock())
# Out:
# Old price: 100
# Old stock: 2
# price updated
# stock update
# New price: 150
# New stock: 7

# %%
# 7 class car 
class car:
    def __init__(self,model,year):
        self.__model=model
        self.__year=year


    def set_model(self,model):
        self.__model=model
    def set_year(self,year):
        if year<=2026:
            self.__year=year
            print("update year")
        else:
            print("year cannot be greater than current year")
    def get_model(self):
        return self.__model

    def get_year(self):
        return self.__year

obj=car("inova",2023)
obj.get_model()
obj.get_year()

obj.set_model("toyato")
obj.set_year(2025)
obj.get_model()
obj.get_year()
# Out:
# update year
# 2025

# %%
class Car:
    def __init__(self, model, year):
        self.__model = model
        self.__year = year

    def set_model(self, model):
        self.__model = model

    def set_year(self, year):
        if year <= 2026:
            self.__year = year
            print("Year updated")
        else:
            print("Year cannot be greater than current year")

    def get_model(self):
        return self.__model

    def get_year(self):
        return self.__year


obj = Car("Innova", 2023)

print("Old model:", obj.get_model())
print("Old year:", obj.get_year())

obj.set_model("Toyota")
obj.set_year(2025)

print("New model:", obj.get_model())
print("New year:", obj.get_year())
# Out:
# Old model: Innova
# Old year: 2023
# Year updated
# New model: Toyota
# New year: 2025

# %%
# class name:user

class user:
    def __init__(self,passw):
        self.__passw=passw

    def change_passw(self,new_passw):
        if len(new_passw)>=8:
            self.__passw=new_passw
            print("valid")
        else:
            print("invalid")

    def get_passw(self):
        return self.__passw

ob=user("abc123")
print("old pass",ob.get_passw())
ob.change_passw("bc123456")
print("new pass",ob.get_passw())
# Out:
# old pass abc123
# valid
# new pass bc123456

# %%
#9 rectangle
class rectangle:
    def __init__(self,leng,wid):
        self.__leng=leng
        self.__wid=wid

    def set_leng(self,leng):
        if leng>0:
            self.__leng=leng
            print("it is positive")
        else:
            print("it not valid")

    def set_wid(self,wid):
        if wid>0:
            self.__wid=wid
            print("valid")
        else:
            print("invalid")
    def area(self):
        area=self.__leng*self.__wid
        print("area of rectangle",area)
    def get_leng(self):
        return self.__leng
    def get_wid(self):
        return self.__wid

obj=rectangle(2,3)
print("old rec",obj.get_leng())
obj.area()
# Out:
# old rec 2
# area of rectangle 6

# %%
# 10 class name: account

class acc:
    history=[]
    def __init__(self,balance):
        self.__balance=balance
        acc.history.append(self.__balance)

    def deposite(self,amount):
        self.__balance+=amount
        acc.history.append(self.__balance)

    def withdraw(self,amount):
        self.__balance-=amount
        acc.history.append(self.__balance)
    def get_deposite(self):
        return self.__balance
    def get_withdraw(self):
        return self.__balance

obj=acc(20000)

print("old balance:",obj.get_deposite())


obj.deposite(1000)
print("new balance:",obj.get_deposite())


obj.withdraw(300)
print("reaming balance after withdraw:",obj.get_deposite())
print("Balance history:", acc.history)
# Out:
# old balance: 20000
# new balance: 21000
# reaming balance after withdraw: 20700
# Balance history: [20000, 21000, 20700]

# %%
# 11 class temp
class temper:
    def __init__(self,celsius):
        self.__celsius=celsius

    def set_celsius(self,celsius):
        self.__celsius=celsius

    def set_celsius(self,celsius):
        self.__celsius=celsius

    def fah(self,celsius):
        fah=(celsius*9/5)+32
        self.__celsius=celsius
    def get_celsius(self):
        self.__celsius=celsius

obj=temper(45)
obj.get_celsius()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 19
#      16         self.__celsius=celsius
#      18 obj=temper(45)
# ---> 19 obj.get_celsius()
#
# Cell In[15], line 16, in temper.get_celsius(self)
#      15 def get_celsius(self):
# ---> 16     self.__celsius=celsius
#
# NameError: name 'celsius' is not defined

# %%
# 12  class name 
class name:

    def __init__(self,price):
        self.__price=price

    def set_price(self):
        if self.__price>500:
            discount=self.__price*10/100
            final_price=self.__price-discount
            self.__price=final_price
            
            print("automa 10% disount")
        else:
            print("do not add discount")

    def get_price(self):
        return self.__price

obj=name(600)
obj.set_price()
obj.get_price()
# Out:
# automa 10% disount
# 540.0

# %%
# 13 name player
class player:
    def __init__(self,score):
        self.__score=score
    def set_score(self,score):
        if score >0:
            self.__score=score
            print("score valid")
        else:
            print(" invalid negative  score")

    def get_score(self):  
         return self.__score

obj=player(67)
print("old score",obj.get_score())
obj.set_score(55)
print("new score",obj.get_score())
# Out:
# old score 67
# score valid
# new score 55

# %%
# 14 class name laptop 
class laptop:
    def __init__(self,ram,storage):
        self.__ram=ram
        self.__storage=storage

    def set_ram(self,ram):
        if self.__ram>0:
            print("it positive")
        else:
            print("it is negative")
    def set_storage(self,storage):
         if  self.__storage>0:
             print("it is positive")


         else:  
             print("it is negative")

    def get_ram(self):
        return self.__ram
    def get_storage(self):
        return self.__storage

obj=laptop(16,512)
print("old laptop details:",obj.get_ram(),obj.get_storage())
obj.set_ram(15)
obj.set_storage(400)
print("new laptop details:",obj.get_ram(),obj.get_storage())
# Out:
# old laptop details: 16 512
# it positive
# it is positive
# new laptop details: 16 512

# %%
# class name employee

class emp:
    def __init__(self,id,salary):
        self.__id=id
        self.__salary=salary

    def get_id(self):
        return self.__id
    def get_salary(self):
        return self.__salary

em=emp(101,50000)
em.get_id()
em.get_salary()
# Out:
# 50000

# %%
# 16 
from abc import ABC, abstractmethod
import math


class Shape(ABC):

    @abstractmethod
    def calculate_area(self):
        pass

    @abstractmethod
    def calculate_perimeter(self):
        pass


class Circle(Shape):
    def __init__(self, radius):
        self.radius = radius

    def calculate_area(self):
        return math.pi * self.radius * self.radius

    def calculate_perimeter(self):
        return 2 * math.pi * self.radius


class Rectangle(Shape):
    def __init__(self, length, width):
        self.length = length
        self.width = width

    def calculate_area(self):
        return self.length * self.width

    def calculate_perimeter(self):
        return 2 * (self.length + self.width)


circle = Circle(5)

print("Circle Area:", circle.calculate_area())
print("Circle Perimeter:", circle.calculate_perimeter())


rectangle = Rectangle(10, 5)

print("Rectangle Area:", rectangle.calculate_area())
print("Rectangle Perimeter:", rectangle.calculate_perimeter())
# Out:
# Circle Area: 78.53981633974483
# Circle Perimeter: 31.41592653589793
# Rectangle Area: 50
# Rectangle Perimeter: 30

# %%
# 17 
from abc import ABC, abstractmethod


class Vehicle(ABC):

    @abstractmethod
    def start(self):
        pass

    @abstractmethod
    def stop(self):
        pass


class Car(Vehicle):

    def start(self):
        print("Car starts with a key")

    def stop(self):
        print("Car stops using brakes")


class Bike(Vehicle):

    def start(self):
        print("Bike starts with a self-start button")

    def stop(self):
        print("Bike stops using brakes")


car = Car()
car.start()
car.stop()

bike = Bike()
bike.start()
bike.stop()
# Out:
# Car starts with a key
# Car stops using brakes
# Bike starts with a self-start button
# Bike stops using brakes

# %%
# 18 
from abc import ABC, abstractmethod


class Payment(ABC):

    @abstractmethod
    def process_payment(self, amount):
        pass


class CreditCardPayment(Payment):

    def process_payment(self, amount):
        print("Processing credit card payment of:", amount)


class UPIPayment(Payment):

    def process_payment(self, amount):
        print("Processing UPI payment of:", amount)


credit_card = CreditCardPayment()
credit_card.process_payment(5000)

upi = UPIPayment()
upi.process_payment(2000)
# Out:
# Processing credit card payment of: 5000
# Processing UPI payment of: 2000

# %%
# 19 
from abc import ABC, abstractmethod


class Animal(ABC):

    @abstractmethod
    def make_sound(self):
        pass


class Dog(Animal):

    def make_sound(self):
        print("Dog says: Woof Woof")


class Cat(Animal):

    def make_sound(self):
        print("Cat says: Meow Meow")


dog = Dog()
dog.make_sound()

cat = Cat()
cat.make_sound()
# Out:
# Dog says: Woof Woof
# Cat says: Meow Meow

# %%
# 20 
from abc import ABC, abstractmethod


class Report(ABC):

    @abstractmethod
    def generate_report(self):
        pass


class PDFReport(Report):

    def generate_report(self):
        print("Generating PDF report")


class ExcelReport(Report):

    def generate_report(self):
        print("Generating Excel report")


pdf = PDFReport()
pdf.generate_report()

excel = ExcelReport()
excel.generate_report()
# Out:
# Generating PDF report
# Generating Excel report
