# %%
n=int(input("entr the value"))
if n>0:
    print("positive")
# Out:
# entr the value 4
# positive

# %%
n=bool(input("enter the value"))
if n==True and n!= True:
    print("true value")
# Out:
# enter the value 3

# %%
 # task 1
numb={1,2,3,4,1}
numb
# Out:
# {1, 2, 3, 4}

# %%
# task 2
s=set()
s.add(3)
print(s)
# Out:
# {3}

# %%
# task 3
s={10,20,30}
s.update({40,50,60})
s
# Out:
# {10, 20, 30, 40, 50, 60}

# %%
# task 4
s={10,20,30,40}
s.remove(20)
print(s)
# Out:
# {40, 10, 30}

# %%
a={10,20,30,40}
a.discard(20)
print(a)
# Out:
# {40, 10, 30}

# %%
# task 5
A={1,2,3,4} 
B={3,4,5,6}
print("union",A.union(B))
print("Intersectio",A.intersection(B))
print("difference",A.difference(B))
# Out:
# union {1, 2, 3, 4, 5, 6}
# Intersectio {3, 4}
# difference {1, 2}

# %%
# task 6
s={10,20,30,40}
print( 25 in s)
# Out:
# False

# %%
# task 7
set=[1,2,3,4,4,5]
print(len(set))
# Out:
# 6

# %%
# task 8
n1=int(input("enter the value"))
n2=int(input("enter the value"))
n3=int(input("enter the value"))
n4=int(input("enter the value"))
n5=int(input("enter the value"))
s={n1,n2,n3,n4,n5}
print(s)
# Out:
# enter the value 44
# enter the value 34
# enter the value 24
# enter the value 33
# enter the value 45
# {33, 34, 44, 45, 24}

# %%
# task 9
a={1,2,3}
b={3,4,5}
a.difference(b)
# Out:
# {1, 2}

# %%
# task 10
c = {10,20}
c.add([1,2,3])
print(c)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[55], line 3
#       1 # task 10
#       2 c = {10,20}
# ----> 3 c.add([1,2,3])
#       4 print(c)
#
# TypeError: unhashable type: 'list'

# %%
# task 11 
age=int(input("enter the value"))
if age>=18 :
    print("eligible")
# Out:
# enter the value 45
# eligible

# %%
# task 12 
n=int(input("enter the value"))
if n>0:
    print("positive")
elif n < 0:
    print("negative")
else:
    print("zero")
# Out:
# enter the value 3
# positive

# %%
# task 13
n1=int(input("enter the value"))
n2=int(input("enter the value"))
if n1>n2:
    print("largestnumber")
else:
    print("not largest")
# Out:
# enter the value 34
# enter the value 45
# not largest

# %%
# task 14
ch=str(input("enter the value"))
if ch in "aeiou":
    print("vowel")
else:
    print("not vowel")
# Out:
# enter the value a
# vowel

# %%
# task 15
marks=int(input("enter the value"))
if marks>=90:
    print("A")
elif marks>=80:
    print("B")
elif marks>=70:
    print("C")
else:
    print("fail")
# Out:
# enter the value 88
# B

# %%
# task 16
n1=int(input("enter the value"))
n2=int(input("enter the value"))
n3=int(input("enter the value"))
if n1>n3:
    print(n1)
elif n2>n3:
    print(n2)
else:
    print(n3)
# Out:
# enter the value 3
# enter the value 4
# enter the value 5
# 5

# %%
# task 17
n=int(input("enter the value"))
if n%2==0 and n>=50:
    print("Yes")
else:
    print("no")
# Out:
# enter the value 34
# no

# %%
# task 18
username=input("enter the value")
password=input("enter the value")
if username=="admin" and password=="123":
    print("login successful")
else:
    print("login failed")
# Out:
# enter the value admin
# enter the value 1234
# login failed

# %%
# task 19
year=int(input("enter the value"))
if (year%4==0 and year %100!=0) or( year%400==0):
    print("leap year")
else:
    print("not leap year")
# Out:
# enter the value 2024
# leap year

# %%
# task 20
n1=int(input("enter the value"))
n2=int(input("enter the value"))
n3=int(input("enter the value"))
s=(n1+n2>n3) and (n2+n1 > n3)
print(s)
# Out:
# enter the value 22
# enter the value 12
# enter the value 67
# False

# %%
# task 21
n1=int(input("enter the value"))
n2=int(input("enter the value"))
n3=int(input("enter the value"))
if n1==n2==n3:
    print("all three number are equal")
elif n1>= n2 and n1>=n3:
    print("largest number",n1)
elif n2>n3 and n2>n1:
    print("largest number",n2)
else:
    print("largest",n3)
# Out:
# enter the value 4
# enter the value 5
# enter the value 6
# largest 6

# %%
# task 23
n1=int(input("enter the value"))
n2=int(input("enter the value"))
n3=int(input("enter the value"))

if (n1+n2>n3)and (n1+n3>n2)and(n2+n3>n1):
    print("valid triangle")
elif n1==n2==n3:
    print("equilateral triangle")
elif n1==n2 or n2==n3 or n1==n3:
    print("isosceles triangle")
else:
    print("scalene")
# Out:
# enter the value 56
# enter the value 34
# enter the value 32
# valid triangle

# %%
# task 24
sub1=int(input("enter the value sub1"))
sub2=int(input("enter the value sub2"))
sub3=int(input("enter the value"))
sub4=int(input("enter the value"))
sub5=int(input("enter the value"))
total=sub1+sub2+sub3+sub4+sub5/500
if total>=90:
    print("A+")
elif total>=80:
    print("A")
elif total>=70:
    print("B")
elif total>=60: 
    print("C")
else:
    print("fail")
# Out:
# enter the value 55
# enter the value 78
# enter the value 88
# enter the value 90
# enter the value 89
# A+
